# %% [markdown]
# # Devendra Sawant
# # Assignment 1
# # GitHub Link :-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1)	Load in the appropriate csv file as a pandas dataframe (batting.csv)

# %%
batting = pd.read_csv('Batting.csv')
batting.fillna(0)
batting.head()
# Out:
#     playerID nameFirst     nameLast  birthYear  yearID  stint teamID lgID   G  \
# 0  abercda01     Frank  Abercrombie       1850    1871      1    TRO  NaN   1
# 1   addybo01       Bob         Addy       1842    1871      1    RC1  NaN  25
# 2  allisar01       Art      Allison       1849    1871      1    CL1  NaN  29
# 3  allisdo01      Doug      Allison       1846    1871      1    WS3  NaN  27
# 4  ansonca01       Cap        Anson       1852    1871      1    RC1  NaN  25
#
#     AB  ...    RBI   SB   CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0    4  ...    0.0  0.0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  118  ...   13.0  8.0  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  137  ...   19.0  3.0  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  133  ...   27.0  1.0  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  120  ...   16.0  6.0  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# # 2)	Print out the dimensions and info about the dataframe you just created

# %%
batting.shape
# Out:
# (102816, 25)

# %%
batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102816 entries, 0 to 102815
# Data columns (total 25 columns):
# playerID     102816 non-null object
# nameFirst    102816 non-null object
# nameLast     102816 non-null object
# birthYear    102816 non-null int64
# yearID       102816 non-null int64
# stint        102816 non-null int64
# teamID       102816 non-null object
# lgID         102079 non-null object
# G            102816 non-null int64
# AB           102816 non-null int64
# R            102816 non-null int64
# H            102816 non-null int64
# 2B           102816 non-null int64
# 3B           102816 non-null int64
# HR           102816 non-null int64
# RBI          102392 non-null float64
# SB           101516 non-null float64
# CS           79360 non-null float64
# BB           102816 non-null int64
# SO           94978 non-null float64
# IBB          66251 non-null float64
# HBP          100006 non-null float64
# SH           96478 non-null float64
# ...

# %%
batting.describe()
# Out:
#            birthYear         yearID          stint              G  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean     1932.991869    1964.262313       1.077838      51.343439
# std        87.105524      38.856297       0.284366      47.121658
# min         0.000000    1871.000000       1.000000       1.000000
# 25%      1905.000000    1934.000000       1.000000      13.000000
# 50%      1945.000000    1973.000000       1.000000      34.000000
# 75%      1969.000000    1998.000000       1.000000      80.000000
# max      1996.000000    2016.000000       5.000000     165.000000
#
#                   AB              R              H             2B  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean      141.905511      18.815544      37.139930       6.289167
# std       184.654492      28.242983      52.603757       9.662468
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#grouping dataframe by column 'playerID' and 'yearID'
groupedByPlayerYearID=batting.groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False).sum()

# %%
groupedByPlayerYearID['PA']= groupedByPlayerYearID['AB']+groupedByPlayerYearID['BB']+groupedByPlayerYearID['IBB']+groupedByPlayerYearID['SF']+groupedByPlayerYearID['SH']
groupedByPlayerYearID['Average']= groupedByPlayerYearID['H']/groupedByPlayerYearID['AB']
groupedByPlayerYearID['OBP']= (groupedByPlayerYearID['H']+groupedByPlayerYearID['BB']+groupedByPlayerYearID['IBB']+groupedByPlayerYearID['SH']+groupedByPlayerYearID['SF']) /groupedByPlayerYearID['AB']

# %% [markdown]
# # 3)	How many players have hit 40 or more HRs in one single season? (Number only)

# %%
groupedByPlayerYearID[groupedByPlayerYearID['HR']>=40]['playerID'].nunique()
# Out:
# 142

# %%
groupedByYear=batting.groupby(['playerID','nameFirst','nameLast'],as_index=False).sum()

# %% [markdown]
# # 4)	How many players have hit more than 600 HRs for their career? (Dataframe)

# %%
groupedByYear[groupedByYear['HR']>600][['playerID','nameFirst','nameLast','HR']]
# Out:
#         playerID nameFirst   nameLast   HR
# 1      aaronha01      Hank      Aaron  755
# 1542   bondsba01     Barry      Bonds  762
# 6633   griffke02       Ken    Griffey  630
# 10857   mayswi01    Willie       Mays  660
# 14528  rodrial01      Alex  Rodriguez  696
# 14865   ruthba01      Babe       Ruth  714
# 16103   sosasa01     Sammy       Sosa  609
# 17004  thomeji01       Jim      Thome  612

# %% [markdown]
# # 5)	How many players have hit 40 2Bs, 10 3Bs, 200 Hits, and 30 HRs (inclusive) in one season? (Number Only)

# %%
groupedByPlayerYearID[(groupedByPlayerYearID['2B']>=40)& (groupedByPlayerYearID['3B']>=10)& (groupedByPlayerYearID['H']>=200)& (groupedByPlayerYearID['HR']>=30)]['playerID'].nunique()
# Out:
# 11

# %% [markdown]
# # 6)	How many players have had 100 or more SBs in a season? (Dataframe)

# %%
groupedByPlayerYearID[groupedByPlayerYearID['SB']>=100][['playerID','nameFirst','nameLast','yearID','SB']].sort_values('SB',ascending=False).reset_index(drop=True)
# Out:
#      playerID nameFirst   nameLast  yearID     SB
# 0   nicolhu01      Hugh      Nicol    1887  138.0
# 1   henderi01    Rickey  Henderson    1982  130.0
# 2   lathaar01     Arlie     Latham    1887  129.0
# 3   brocklo01       Lou      Brock    1974  118.0
# 4   comisch01   Charlie   Comiskey    1887  117.0
# 5   hamilbi01     Billy   Hamilton    1889  111.0
# 6    wardjo01      John       Ward    1887  111.0
# 7   hamilbi01     Billy   Hamilton    1891  111.0
# 8   colemvi01     Vince    Coleman    1985  110.0
# 9   colemvi01     Vince    Coleman    1987  109.0
# 10  lathaar01     Arlie     Latham    1888  109.0
# 11  henderi01    Rickey  Henderson    1983  108.0
# 12  colemvi01     Vince    Coleman    1986  107.0
# 13  brownto01       Tom      Brown    1891  106.0
# 14  willsma01     Maury      Wills    1962  104.0
# 15  brownpe01      Pete   Browning    1887  103.0
# 16  nicolhu01      Hugh      Nicol    1888  103.0
# 17  fogarji01       Jim    Fogarty    1887  102.0
# ...

# %% [markdown]
# # 7)	How many players in the 1960s have hit more than 200 HRs? (Dataframe)

# %%
HRIn1960s=batting[(batting['yearID']>=1960) & (batting['yearID']<=1969)].groupby(['playerID','nameFirst','nameLast']).sum()
HRIn1960s[HRIn1960s['HR']>200]['HR']
# Out:
# playerID   nameFirst  nameLast
# aaronha01  Hank       Aaron          375
# allisbo01  Bob        Allison        225
# bankser01  Ernie      Banks          269
# cashno01   Norm       Cash           278
# cepedor01  Orlando    Cepeda         254
# colavro01  Rocky      Colavito       245
# howarfr01  Frank      Howard         288
# kalinal01  Al         Kaline         210
# killeha01  Harmon     Killebrew      393
# mantlmi01  Mickey     Mantle         256
# marisro01  Roger      Maris          217
# matheed01  Eddie      Mathews        213
# mayswi01   Willie     Mays           350
# mccovwi01  Willie     McCovey        300
# powelbo01  Boog       Powell         202
# robinfr02  Frank      Robinson       316
# santoro01  Ron        Santo          253
# willibi01  Billy      Williams       249
# yastrca01  Carl       Yastrzemski    202
# Name: HR, dtype: int64

# %% [markdown]
# # 8)	Who has hit the most HRs in history? (Dataframe)

# %%
groupedByYear[['playerID', 'HR']].sort_values(['HR','playerID'], ascending=[False, True]).head(1)
# Out:
#        playerID   HR
# 1542  bondsba01  762

# %% [markdown]
# # 9)	Who had the most hits in the 1970s? (Dataframe)

# %%
HRIn1970s=batting[(batting['yearID']>=1970) & (batting['yearID']<=1979)].groupby(['playerID','nameFirst','nameLast']).sum()
HRIn1970s['HR'].sort_values(ascending=False).head(1)
# Out:
# playerID   nameFirst  nameLast
# stargwi01  Willie     Stargell    296
# Name: HR, dtype: int64

# %% [markdown]
# # 10)	Top 5 highest OBP (on base percentage) with at least 500 PAs in 1977?

# %%
OBPIn1977=batting[batting['yearID']==1977].groupby(['playerID','nameFirst','nameLast'],as_index=False ).sum()
OBPIn1977['PA']= OBPIn1977['AB']+OBPIn1977['BB']+OBPIn1977['IBB']+OBPIn1977['SF']+OBPIn1977['SH']

OBPIn1977['OBP']= (OBPIn1977['H']+OBPIn1977['BB']+OBPIn1977['IBB']+OBPIn1977['SH']+OBPIn1977['SF']) /OBPIn1977['AB']

OBPIn1977[OBPIn1977['PA']>=500][['playerID','nameFirst','nameLast','OBP']].sort_values('OBP',ascending=False).reset_index(drop=True).head(5)
# Out:
#     playerID nameFirst   nameLast       OBP
# 0  singlke01       Ken  Singleton  0.563433
# 1  smithre06    Reggie      Smith  0.559426
# 2  tenacge01      Gene     Tenace  0.556064
# 3  hargrmi01      Mike   Hargrove  0.540952
# 4  carewro01       Rod      Carew  0.534091

# %% [markdown]
# # 11)	Top 8 highest averages in 2013 with at least 300 PAs? (Dataframe)

# %%
AvgIn2013=batting[batting['yearID']==2013].groupby(['playerID','nameFirst','nameLast'],as_index=False ).sum()
AvgIn2013['Average']= AvgIn2013['H']/AvgIn2013['AB']
AvgIn2013['PA']= AvgIn2013['AB']+AvgIn2013['BB']+AvgIn2013['IBB']+AvgIn2013['SF']+AvgIn2013['SH']
AvgIn2013[AvgIn2013['PA']>=300][['playerID','nameFirst','nameLast','Average']].sort_values('Average',ascending=False).reset_index(drop=True).head(8)
# Out:
#     playerID nameFirst nameLast   Average
# 0  cabremi01    Miguel  Cabrera  0.347748
# 1  ramirha01    Hanley  Ramirez  0.345395
# 2  cuddymi01   Michael  Cuddyer  0.331288
# 3  mauerjo01       Joe    Mauer  0.323596
# 4  troutmi01      Mike    Trout  0.322581
# 5  johnsch05     Chris  Johnson  0.321012
# 6  freemfr01   Freddie  Freeman  0.319419
# 7   puigya01    Yasiel     Puig  0.319372

# %% [markdown]
# # 12)Leaders in hits from 1940 up to and including 1949. (Dataframe)¶

# %%
leardeHits1940= batting[(batting['yearID'] >= 1940) & (batting['yearID'] <= 1949) ].groupby(['playerID','nameFirst','nameLast'],as_index=False ).sum()

leardeHits1940[['playerID','nameFirst','nameLast','H']].sort_values('H',ascending=False).reset_index(drop=True).head(10)
# Out:
#     playerID nameFirst    nameLast     H
# 0  boudrlo01       Lou    Boudreau  1578
# 1  elliobo01       Bob     Elliott  1563
# 2  walkedi02     Dixie      Walker  1512
# 3  musiast01      Stan      Musial  1432
# 4  doerrbo01     Bobby       Doerr  1407
# 5  holmeto01     Tommy      Holmes  1402
# 6  applilu01      Luke     Appling  1376
# 7  nichobi01      Bill   Nicholson  1328
# 8  marioma01     Marty      Marion  1310
# 9  cavarph01      Phil  Cavarretta  1304

# %% [markdown]
# # 13)	Who led MLB with the most hits the most times?  And how many times?  (Dataframe, Number)

# %%
#grouping data by yearID
groupedByYear=batting.groupby(['yearID','nameFirst','nameLast','playerID'],as_index=False).sum()

# getting list of years
seasons=groupedByYear['yearID'].unique()

playername= []
for year in seasons:
    maxhits=groupedByYear[groupedByYear['yearID']==year]['H'].max()
    playername.append(groupedByYear[(groupedByYear['yearID']==year) & (groupedByYear['H']==maxhits)]['playerID'].get_values())

#flattening list of players    
import itertools
flattened_list  = list(itertools.chain(*playername))

#counting 
from collections import Counter
sortedList=Counter(flattened_list).most_common()

hitsLeader=pd.DataFrame(sortedList,columns=['playerID','no of time le dmots hits'])
hitsLeader.head(5)
# Out:
#     playerID  no of time le dmots hits
# 0   cobbty01                         7
# 1   rosepe01                         7
# 2  suzukic01                         7
# 3  musiast01                         5
# 4  gwynnto01                         5

# %% [markdown]
# # 14) Which players have played the most games for their careers?  Top 5, descending by games played presented as a dataframe

# %%
groupedByYear[['playerID','G']].sort_values('G',ascending=False).reset_index(drop=True).head(5)
# Out:
#     playerID    G
# 0  willsma01  165
# 1  santoro01  164
# 2  willibi01  164
# 3  tovarce01  164
# 4  taverfr01  164

# %% [markdown]
# # 15 How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here

# %%
#15 How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here
groupedByYear[(groupedByYear['H']>3000)& (groupedByYear['HR']>500)]['playerID'].nunique()
# Out:
# 0

# %% [markdown]
# # 16 How many HRs were hit during the entire 1988 season?  Just a number is okay here

# %%
batting[batting['yearID']==1988]['HR'].sum()
# Out:
# 3180

# %% [markdown]
# # 17) Please filter out and show me the top 3 average seasons by Wade Boggs during his career in seasons in which he had at least 500 ABs.  I would like a dataframe sorted by average.

# %%
wadeBoggs= batting[batting['playerID']=='boggswa01'].groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False ).sum()
wadeBoggs['Average']= wadeBoggs['H']/wadeBoggs['AB']
wadeBoggs[['playerID','nameFirst','nameLast','yearID','Average']].sort_values('Average',ascending=False).reset_index(drop=True).head(3)
# Out:
#     playerID nameFirst nameLast  yearID   Average
# 0  boggswa01      Wade    Boggs    1985  0.367534
# 1  boggswa01      Wade    Boggs    1988  0.366438
# 2  boggswa01      Wade    Boggs    1987  0.362976

# %% [markdown]
# # 18 Please filter out the top OBPs for the 1995 season with at least 400 PAs, sorted by OBP.  I would like a dataframe for this

# %%
OBPIn1995=batting[batting['yearID']==1995].groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False ).sum()
OBPIn1995['PA']= OBPIn1995['AB']+OBPIn1995['BB']+OBPIn1995['IBB']+OBPIn1995['SF']+OBPIn1995['SH']

OBPIn1995['OBP']= (OBPIn1995['H']+OBPIn1995['BB']+OBPIn1995['IBB']+OBPIn1995['SH']+OBPIn1995['SF']) /OBPIn1995['AB']

OBPIn1995[OBPIn1995['PA']>=400][['playerID','nameFirst','nameLast','OBP']].sort_values('OBP',ascending=False).reset_index(drop=True).head(5)
# Out:
#     playerID nameFirst  nameLast       OBP
# 0  thomafr04     Frank    Thomas  0.667343
# 1  martied01     Edgar  Martinez  0.628180
# 2  mcgwima01      Mark   McGwire  0.586751
# 3  bondsba01     Barry     Bonds  0.583004
# 4  davisch01     Chili     Davis  0.577830

# %% [markdown]
# # 19) Who had the most 3Bs (in total) in 1922, 1925, 1926, and 1928?  I would like a dataframe with just the leader

# %%
most3BIn1922 = groupedByPlayerYearID[groupedByPlayerYearID['yearID']==1922][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1)
most3BIn1925 = groupedByPlayerYearID[groupedByPlayerYearID['yearID']==1925][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1)
most3BIn1926 = groupedByPlayerYearID[groupedByPlayerYearID['yearID']==1926][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1)
most3BIn1928 = groupedByPlayerYearID[groupedByPlayerYearID['yearID']==1928][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1)
pd.concat([most3BIn1922,most3BIn1925,most3BIn1926,most3BIn1928])
# Out:
#        yearID   playerID nameFirst nameLast  3B
# 19726    1922  daubeja01      Jake  Daubert  22
# 19217    1925  cuyleki01      Kiki   Cuyler  26
# 89749    1926  wanerpa01      Paul    Waner  22
# 16668    1928  combsea01     Earle    Combs  21

# %% [markdown]
# # 20) How many players have hit 30 or more HRs in season while also stealing (SB) 30 more or bases?  A number is okay here

# %%
groupedByPlayerYearID[(groupedByPlayerYearID['HR']>= 30)& (groupedByPlayerYearID['SB']>=30)]['playerID'].nunique()
# Out:
# 38

# %% [markdown]
# # 21) Who had the highest OBP is 1986 with at least 400 PAs?

# %%
OBPIn1986=batting[batting['yearID']==1986].groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False ).sum()
OBPIn1986['PA']= OBPIn1986['AB']+OBPIn1986['BB']+OBPIn1986['IBB']+OBPIn1986['SF']+OBPIn1986['SH']

OBPIn1986['OBP']= (OBPIn1986['H']+OBPIn1986['BB']+OBPIn1986['IBB']+OBPIn1986['SH']+OBPIn1986['SF']) /OBPIn1986['AB']

OBPIn1986[OBPIn1986['PA']>=400][['playerID','nameFirst','nameLast','OBP']].sort_values('OBP',ascending=False).head(1)
# Out:
#      playerID nameFirst nameLast       OBP
# 78  boggswa01      Wade    Boggs  0.575862

# %% [markdown]
# # 22) Same question but for 1997 and only in the NL (check league ID)? (Dataframe)

# %%
OBPIn1997=batting[(batting['yearID']==1997) & (batting['lgID'] == 'NL')].groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False ).sum()
OBPIn1997['PA']= OBPIn1997['AB']+OBPIn1997['BB']+OBPIn1997['IBB']+OBPIn1997['SF']+OBPIn1997['SH']

OBPIn1997['OBP']= (OBPIn1997['H']+OBPIn1997['BB']+OBPIn1997['IBB']+OBPIn1997['SH']+OBPIn1997['SF']) /OBPIn1997['AB']

OBPIn1997[OBPIn1997['PA']>=400][['playerID','nameFirst','nameLast','OBP']].sort_values('OBP',ascending=False).head(1)
# Out:
#      playerID nameFirst nameLast       OBP
# 60  bondsba01     Barry    Bonds  0.637218

# %% [markdown]
# # 23) Who had more than the league average HRs in 2012 (filter out all players with less 500 PAs)? (Dataframe)

# %%
#filtering data for year 2012
averageHRIn2012= batting[batting['yearID']==2012].groupby(['playerID','nameFirst','nameLast','yearID','lgID'],as_index=False ).sum()
averageHRIn2012['PA']= averageHRIn2012['AB']+averageHRIn2012['BB']+averageHRIn2012['IBB']+averageHRIn2012['SF']+averageHRIn2012['SH']

#calculating average HR for league AL and NL
averageHRIn2012AL=averageHRIn2012[averageHRIn2012['lgID']=='AL']['HR'].mean()
averageHRIn2012NL=averageHRIn2012[averageHRIn2012['lgID']=='NL']['HR'].mean()

# filtering ount row with PA < 500
averageHRIn2012=averageHRIn2012[averageHRIn2012['PA']>=500].reset_index(drop=True)

dictobj= {}
for i in range(0,len(averageHRIn2012)):
    if (averageHRIn2012.loc[i,'lgID']=='NL'):
        if (averageHRIn2012.loc[i,'HR']> averageHRIn2012NL):
            l[averageHRIn2012.loc[i,'playerID']]=averageHRIn2012.loc[i,'HR']
    elif (averageHRIn2012.loc[i,'HR']> averageHRIn2012AL):
        l[averageHRIn2012.loc[i,'playerID']]=averageHRIn2012.loc[i,'HR']

# creating dataframe        
playerToScoreMoreHRThanAverage=pd.DataFrame(list(l.items()),columns=['playerID', 'HR']).reset_index(drop=True)
playerToScoreMoreHRThanAverage
# Out:
#       playerID  HR
# 0    amarial01   5
# 1    andinro01   7
# 2    ankieri01   5
# 3    arencjp01  18
# 4    ariasjo01   5
# 5    avilaal01   9
# 6    bakerje03   4
# 7    barajro01  11
# 8    barmecl01   8
# 9    bautijo02  27
# 10     bayja01   8
# 11    beltbr01   7
# 12   bernaro01   5
# 13   betanyu01   7
# 14   betemwi01  12
# 15   blancgr01   5
# 16   boescbr01  12
# 17   bogusbr01   7
# 18   brownan02   5
# 19   browndo01   5
# 20    buckjo01  12
# 21    cainlo01   7
# 22   carpema01   6
# 23    carpmi01   5
# 24   cartech02  16
# 25   castiwe01   5
# 26   castrja01   6
# 27   cedenro02   4
# 28   chaveer01  16
# 29   chiselo01   5
# ..         ...  ..
# 295  rolliji01  23
# 296   rossco01  22
# 297  santaca01  18
# 298  saundmi01  19
# 299  scutama01   7
# 300  seageky01  20
# 301  smoakju01  19
# 302  soriaal01  32
# 303   spande01   4
# 304  stantmi03  37
# 305  stubbdr01  14
# 306  suzukic01   9
# 307  swishni01  24
# 308  teixema01  24
# 309  troutmi01  30
# ...

# %% [markdown]
# # 24) Who is the youngest player to hit 50 or more HRs in a single season? (Dataframe)

# %%
youngestPlayerToHit50HR= batting.groupby(['playerID','nameFirst','nameLast','yearID','birthYear'],as_index=False ).sum()
youngestPlayerToHit50HR['Age']= youngestPlayerToHit50HR['yearID']-youngestPlayerToHit50HR['birthYear']
youngestPlayerToHit50HR[youngestPlayerToHit50HR['HR']>=50][['playerID','nameFirst','nameLast','yearID','birthYear','HR','Age']].sort_values('Age').reset_index(drop=True)
# Out:
#      playerID nameFirst   nameLast  yearID  birthYear  HR  Age
# 0   fieldpr01    Prince    Fielder    2007       1984  50   23
# 1    mayswi01    Willie       Mays    1955       1931  51   24
# 2   mantlmi01    Mickey     Mantle    1956       1931  52   25
# 3   kinerra01     Ralph      Kiner    1947       1922  51   25
# 4    foxxji01    Jimmie       Foxx    1932       1907  58   25
# 5    ruthba01      Babe       Ruth    1920       1895  54   25
# 6    ruthba01      Babe       Ruth    1921       1895  59   26
# 7   rodrial01      Alex  Rodriguez    2001       1975  52   26
# 8   kinerra01     Ralph      Kiner    1949       1922  54   27
# 9   howarry01      Ryan     Howard    2006       1979  58   27
# 10  greenha01      Hank  Greenberg    1938       1911  58   27
# 11  rodrial01      Alex  Rodriguez    2002       1975  57   27
# 12  fieldce01     Cecil    Fielder    1990       1963  51   27
# 13  davisch02     Chris      Davis    2013       1986  53   27
# ...

# %% [markdown]
# # 25) Who are the five youngest players to hit 300 or more HRs for their career? (Dataframe)

# %%
# creating dataframe grouped by playerID and yearID
groupebyPlayerandYear=batting.groupby(['playerID','nameFirst','nameLast','yearID','birthYear'],as_index=False ).sum().sort_values(['playerID','yearID'])

# genearting list of player who scored 300 or more HR's in there career
totalHRofPlayers=batting.groupby('playerID',as_index=False).sum()
playernames=totalHRofPlayers[totalHRofPlayers['HR']>=300]['playerID'].unique()

# %%
# creating dictionary object to collect age of players when they have scored 300HR
dictobj={}
for player in playernames:
    #print(player)
    years=groupebyPlayerandYear[groupebyPlayerandYear['playerID']==player]['yearID']
    HR=0
    dob=groupebyPlayerandYear[groupebyPlayerandYear['playerID']==player]['birthYear'].unique()[0]
    #print('dob',dob)
    for year in years:
        
    
      
        HR=HR+groupebyPlayerandYear[(groupebyPlayerandYear['playerID']==player) &(groupebyPlayerandYear['yearID']==year) ]['HR'].get_values()[0]
      
        if (HR >= 300):
            #print(year)
            dictobj[player]=(year-dob)
            #print('obj added',(year-dob))
           
            break
 
# creating dataframe from dictionary object

yougestplayertoScore300HR=pd.DataFrame(list(dictobj.items()),columns=['playerID', 'Age']).sort_values('Age').reset_index(drop=True)
yougestplayertoScore300HR.head(5)
# Out:
#     playerID  Age
# 0   foxxji01   28
# 1    ottme01   28
# 2  pujolal01   28
# 3  jonesan01   28
# 4  rodrial01   28

# %% [markdown]
# # Graph total HRs per season using bar graph

# %%
df_grpby = batting[['yearID','HR']].groupby(['yearID'], as_index=False).sum()
x = df_grpby['yearID']
y = df_grpby['HR']
fig = plt.figure()
fig.suptitle('Total HR per Season', fontsize=30)

plt.rc('axes', labelsize=font_label)
plt.rcParams['figure.figsize']=(20,20)
plt.bar(x, y, align='center')
plt.xlabel('Year')
plt.ylabel('HR')
# Out:
# Text(0,0.5,'HR')

# %% [markdown]
# # Using a line graph please graph the average HRs per AB (think about this) per season

# %%
averageHRperABperSeason=batting.groupby('yearID',as_index=False).sum()[['yearID','AB','HR']]
averageHRperABperSeason['average']=averageHRperABperSeason['HR']/averageHRperABperSeason['AB']
averageHRperABperSeason.plot('yearID','average')
plt.xlabel('Year')
plt.ylabel('Average HR per AB')
# Out:
# Text(0,0.5,'Average HR per AB')
